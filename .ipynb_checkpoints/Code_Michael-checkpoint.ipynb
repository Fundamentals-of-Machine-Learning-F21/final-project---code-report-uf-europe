# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Loading Data
labels_names =['Stadium','Building','Traffic Sign','Forest','Flowers',
              'Street','Classroom','Bridge','Statue','Lake']
data_train = np.load('data_train.npy')
labels_train = np.load('labels_train.npy')
labels_train = labels_train.astype(int)

#train_dataset = tf.data.Dataset.from_tensor_slices((data_train, labels_train))

# %%
from PIL import Image
import os
import errno
#Converting data to directory
transposed_data = data_train.T

for idx, l in np.ndenumerate(labels_train):
   # data = data_train[:,idx]
    data = transposed_data[idx]
    img = Image.fromarray( data.reshape((300,300,3)), 'RGB')
    labelNr = l - 1
    filename = f'KerasPrep/{labelNr}/{idx[0]}.jpg'
    if not os.path.exists(os.path.dirname(filename)):
        try:
            os.makedirs(os.path.dirname(filename))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
    img.save(filename)

# %%
from tensorflow.keras.applications import ResNet50
def build_retrained_model(batch_size, img_height, img_width, data_dir, validation_split,random_rotation,random_zoom,dropout,base_learning_rate):
    # dividing in classes train and validation
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="training",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)

    num_classes = len(train_ds.class_names)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="validation",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)
    
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
    
     #flip the images and rotate and zoom to increase generalization.
    data_augmentation = keras.Sequential(
      [
        layers.RandomFlip("horizontal",
                          input_shape=(img_height,
                                      img_width,
                                      3)),
        layers.RandomContrast(0.2),
        layers.RandomRotation(random_rotation),
        layers.RandomZoom(random_zoom),
        layers.Rescaling(1./255),
      ]
    )
    
    model = Sequential([
        data_augmentation,
      ResNet50(include_top=False, weights='imagenet', pooling='max'),
        layers.Flatten(),
      layers.Dense(1028, activation='relu'),
      layers.Dropout(dropout2),
      layers.Dense(num_classes)
    ])
    
    return model, train_ds, val_ds

# Parameters for the Model
batch_size = 32
img_height = 224
img_width = 224
data_dir = 'KerasPrep'
validation_split = 0.2
random_rotation = 0.35
random_zoom = 0.35
dropout = 0.24
epochs=10
base_learning_rate = 0.0001
IMG_SHAPE = (224, 224) + (3,)


base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False
# build model
model, train_ds, val_ds = build_retrained_model(batch_size, img_height, img_width, data_dir, 
                                             validation_split,random_rotation,random_zoom,
                                             dropout,base_learning_rate)
# use adam model optimizer.
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
model.summary()
#train model
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Found 6248 files belonging to 10 classes.
# Using 4999 files for training.
# Found 6248 files belonging to 10 classes.
# Using 1249 files for validation.
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_38 (Sequential)   (None, 224, 224, 3)       0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1028)              2106372
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1028)              0
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                10290
# =================================================================
# Total params: 25,704,374
# Trainable params: 25,651,254
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/10
# 157/157 [==============================] - 24s 78ms/step - loss: 2.4978 - accuracy: 0.6485 - val_loss: 13.7461 - val_accuracy: 0.1097
# Epoch 2/10
# 157/157 [==============================] - 10s 67ms/step - loss: 0.7206 - accuracy: 0.8302 - val_loss: 5.4216 - val_accuracy: 0.1185
# Epoch 3/10
# 157/157 [==============================] - 10s 66ms/step - loss: 0.4801 - accuracy: 0.8780 - val_loss: 4.9060 - val_accuracy: 0.1713
# Epoch 4/10
# 157/157 [==============================] - 11s 69ms/step - loss: 0.3575 - accuracy: 0.9044 - val_loss: 2.4664 - val_accuracy: 0.4155
# Epoch 5/10
# 157/157 [==============================] - 10s 66ms/step - loss: 0.2908 - accuracy: 0.9244 - val_loss: 1.4534 - val_accuracy: 0.7174
# Epoch 6/10
# 157/157 [==============================] - 10s 66ms/step - loss: 0.2374 - accuracy: 0.9354 - val_loss: 0.5326 - val_accuracy: 0.8919
# Epoch 7/10
# 157/157 [==============================] - 11s 69ms/step - loss: 0.2184 - accuracy: 0.9402 - val_loss: 0.3310 - val_accuracy: 0.9464
# Epoch 8/10
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1964 - accuracy: 0.9460 - val_loss: 1.7586 - val_accuracy: 0.8735
# Epoch 9/10
# 157/157 [==============================] - 11s 69ms/step - loss: 0.2075 - accuracy: 0.9538 - val_loss: 1.3293 - val_accuracy: 0.9135
# Epoch 10/10
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1857 - accuracy: 0.9568 - val_loss: 0.7733 - val_accuracy: 0.9440

# %%
# Fine-tune from this layer onwards
fine_tune_at = 100
base_model.trainable = True
# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False
    
model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
total_epochs =  epochs + 30

history_fine = model.fit(train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_ds)
# Out:
# Epoch 10/40
# 157/157 [==============================] - 17s 71ms/step - loss: 0.1078 - accuracy: 0.9760 - val_loss: 0.1208 - val_accuracy: 0.9672
# Epoch 11/40
# 157/157 [==============================] - 11s 70ms/step - loss: 0.0992 - accuracy: 0.9784 - val_loss: 0.0917 - val_accuracy: 0.9728
# Epoch 12/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 0.0935 - val_accuracy: 0.9760
# Epoch 13/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0407 - accuracy: 0.9878 - val_loss: 0.0875 - val_accuracy: 0.9744
# Epoch 14/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0362 - accuracy: 0.9874 - val_loss: 0.1090 - val_accuracy: 0.9728
# Epoch 15/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.1126 - val_accuracy: 0.9744
# Epoch 16/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0277 - accuracy: 0.9930 - val_loss: 0.1019 - val_accuracy: 0.9752
# Epoch 17/40
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.1086 - val_accuracy: 0.9752
# Epoch 18/40
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0235 - accuracy: 0.9920 - val_loss: 0.0973 - val_accuracy: 0.9752
# Epoch 19/40
# 157/157 [==============================] - 11s 70ms/step - loss: 0.0192 - accuracy: 0.9930 - val_loss: 0.0984 - val_accuracy: 0.9792
# Epoch 20/40
# 157/157 [==============================] - 10s 67ms/step - loss: 0.0195 - accuracy: 0.9954 - val_loss: 0.1024 - val_accuracy: 0.9784
# Epoch 21/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.0985 - val_accuracy: 0.9800
# Epoch 22/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.0983 - val_accuracy: 0.9792
# Epoch 23/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0845 - val_accuracy: 0.9840
# Epoch 24/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 0.0862 - val_accuracy: 0.9832
# Epoch 25/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.0829 - val_accuracy: 0.9872
# Epoch 26/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.1100 - val_accuracy: 0.9824
# Epoch 27/40
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.1111 - val_accuracy: 0.9792
# Epoch 28/40
# 157/157 [==============================] - 11s 70ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.1000 - val_accuracy: 0.9848
# Epoch 29/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.1079 - val_accuracy: 0.9848
# Epoch 30/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.1029 - val_accuracy: 0.9856
# Epoch 31/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0919 - val_accuracy: 0.9872
# Epoch 32/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0086 - accuracy: 0.9966 - val_loss: 0.1038 - val_accuracy: 0.9840
# Epoch 33/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.1030 - val_accuracy: 0.9848
# Epoch 34/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.0954 - val_accuracy: 0.9864
# Epoch 35/40
# 157/157 [==============================] - 11s 67ms/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.0997 - val_accuracy: 0.9824
# Epoch 36/40
# 157/157 [==============================] - 11s 70ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.1052 - val_accuracy: 0.9800
# Epoch 37/40
# 157/157 [==============================] - 10s 67ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.1088 - val_accuracy: 0.9856
# Epoch 38/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.1044 - val_accuracy: 0.9856
# Epoch 39/40
# 157/157 [==============================] - 11s 69ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.1128 - val_accuracy: 0.9848
# Epoch 40/40
# 157/157 [==============================] - 10s 66ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.1104 - val_accuracy: 0.9888

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

acc_fine = history_fine.history['accuracy']
val_acc_fine = history_fine.history['val_accuracy']

loss_fine = history_fine.history['loss']
val_loss_fine = history_fine.history['val_loss']

epochs_range = range(total_epochs + 1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc + acc_fine, label='Training Accuracy')
plt.plot(epochs_range, val_acc + val_acc_fine, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss + loss_fine, label='Training Loss')
plt.plot(epochs_range, val_loss + val_loss_fine, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def build_custom_model(batch_size, img_height, img_width, data_dir, validation_split,random_rotation,random_zoom,dropout,dropout2,number_of_layers,batch_normalization,start_neurons):
    # dividing in classes train and validation
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="training",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)

    num_classes = len(train_ds.class_names)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="validation",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)

    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

    #flip the images and rotate and zoom to increase generalization.
    data_augmentation = keras.Sequential(
      [
        layers.RandomFlip("horizontal",
                          input_shape=(img_height,
                                      img_width,
                                      3)),
        layers.RandomContrast(0.2),
        layers.RandomRotation(random_rotation),
        layers.RandomZoom(random_zoom),
        layers.RandomInvert(),
        layers.Rescaling(1./255),
      ]
    )
    # Building the sequential model with relu acitivation function
    
    main_model = []
    
    for layer in range((number_of_layers)):
        main_model += [layers.Conv2D((start_neurons * (2**layer)), 3, padding='same', activation='relu'),
                       layers.MaxPooling2D(2),
                       layers.Dropout(dropout)]
        
        if batch_normalization:
            main_model.append(layers.BatchNormalization())
    
    model = Sequential([
      data_augmentation,
        
        keras.Sequential(main_model),
        
      layers.Flatten(),
      layers.Dense((start_neurons * (2**(number_of_layers-1))), activation='relu'),
      layers.Dropout(dropout2),
      layers.Dense(num_classes)
    ])
    
    # use adam model optimizer.
   
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    """
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                  metrics=[keras.metrics.TopKCategoricalAccuracy(k=3, name='acc_top3'),
                       keras.metrics.TopKCategoricalAccuracy(k=1, name='acc_top1')])
    """

    model.summary()
    return model, train_ds, val_ds

# %%
# Parameters for the Model
batch_size = 32
img_height = 300
img_width = 300
data_dir = 'KerasPrep'
validation_split = 0.2
random_rotation = 0.35
random_zoom = 0.35
dropout = 0.3
dropout2 = 0.31
start_neurons = 128
number_of_layers = 2
batch_normalization = False
epochs=230

# build model
model, train_ds, val_ds = build_custom_model(batch_size, img_height, img_width, data_dir, 
                                             validation_split,random_rotation,random_zoom,
                                             dropout,dropout2,number_of_layers,batch_normalization,
                                             start_neurons)

#train model
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0.001, patience=6, verbose=0, mode='max',
    baseline=None, restore_best_weights=True
)


history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  #callbacks = [callback]
)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

  
fields=[epochs,acc,img_height, img_width, data_dir, validation_split,random_rotation,random_zoom,dropout,val_acc,batch_size, model.get_config()]
with open(r'ML_results', 'a') as f:
    writer = csv.writer(f)
    writer.writerow(fields)
