# %%
import numpy as np
# Loading Data
labels_names =['Stadium','Building','Traffic Sign','Forest','Flowers',
              'Street','Classroom','Bridge','Statue','Lake']
data_train = np.load('data_train.npy')
labels_train = np.load('labels_train.npy')
labels_train = labels_train.astype(int)

#train_dataset = tf.data.Dataset.from_tensor_slices((data_train, labels_train))

# %%
from PIL import Image
import os
import errno
#Converting data to directory
transposed_data = data_train.T

for idx, l in np.ndenumerate(labels_train):
   # data = data_train[:,idx]
    data = transposed_data[idx]
    img = Image.fromarray( data.reshape((300,300,3)), 'RGB')
    labelNr = l - 1
    filename = f'KerasPrep/{labels_names[labelNr]}/{idx[0]}.jpg'
    if not os.path.exists(os.path.dirname(filename)):
        try:
            os.makedirs(os.path.dirname(filename))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
    img.save(filename)

# %% [markdown]
# batch size 32
# layers.RandomRotation(0.1),
# layers.RandomZoom(0.1),
# layers.Dropout(0.1),
# randomflip: horizontal
#
# -> Generalization 0.65
#
#
# increased dropout to 0.2, added layer 128

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


def build_custom_model(batch_size, img_height, img_width, data_dir, validation_split,random_rotation,random_zoom,dropout):
    # dividing in classes train and validation 0.8 / 0.2
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="training",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)

    num_classes = len(train_ds.class_names)
    print(num_classes)

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
      data_dir,
      validation_split=validation_split,
      subset="validation",
      seed=123,
      image_size=(img_height, img_width),
      batch_size=batch_size)

    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

    #flip the images and rotate and zoom to increase generalization.
    data_augmentation = keras.Sequential(
      [
        layers.RandomFlip("horizontal",
                          input_shape=(img_height,
                                      img_width,
                                      3)),
        layers.RandomRotation(random_rotation),
        layers.RandomZoom(random_zoom),
      ]
    )
    # Building the sequential model with relu acitivation function
    model = Sequential([
      data_augmentation,
      layers.Rescaling(1./255),
      layers.Conv2D(32, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(64, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(128, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(256, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(256, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(dropout),
      layers.Flatten(),
      layers.Dense(512, activation='relu'),
      layers.Dense(num_classes)
    ])

    # use adam model optimizer.
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    model.summary()
# Out:
# Found 3124 files belonging to 10 classes.
# Using 2500 files for training.
# 10
# Found 3124 files belonging to 10 classes.
# Using 624 files for validation.
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_10 (Sequential)   (None, 300, 300, 3)       0
# _________________________________________________________________
# rescaling_5 (Rescaling)      (None, 300, 300, 3)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 37, 37, 256)       295168
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 18, 18, 256)       590080
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 9, 9, 256)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 20736)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               10617344
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 11,600,970
# Trainable params: 11,600,970
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 24
img_height = 300
img_width = 300
data_dir = 'KerasPrep'
validation_split = 0.2
random_rotation = 0.3
random_zoom = 0.3
dropout = 0.3
build_custom_model(batch_size, img_height, img_width, data_dir, validation_split,random_rotation,random_zoom,drop

# %%
#train model

epochs=60
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/60
# 105/105 [==============================] - 9s 32ms/step - loss: 2.2072 - accuracy: 0.1836 - val_loss: 2.0550 - val_accuracy: 0.3574
# Epoch 2/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1.8890 - accuracy: 0.3368 - val_loss: 1.7663 - val_accuracy: 0.3750
# Epoch 3/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1.6924 - accuracy: 0.4100 - val_loss: 1.8983 - val_accuracy: 0.3365
# Epoch 4/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1.6047 - accuracy: 0.4364 - val_loss: 1.5499 - val_accuracy: 0.4567
# Epoch 5/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1.5046 - accuracy: 0.4788 - val_loss: 1.3895 - val_accuracy: 0.5401
# Epoch 6/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1.4711 - accuracy: 0.4900 - val_loss: 1.4970 - val_accuracy: 0.4696
# Epoch 7/60
# 105/105 [==============================] - 2s 16ms/step - loss: 1
60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.6164 - accuracy: 0.7752 - val_loss: 0.8584 - val_accuracy: 0.7324
# Epoch 36/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5983 - accuracy: 0.7844 - val_loss: 0.9605 - val_accuracy: 0.7019
# Epoch 37/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5770 - accuracy: 0.7996 - val_loss: 0.8861 - val_accuracy: 0.7067
# Epoch 38/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.6342 - accuracy: 0.7708 - val_loss: 0.9886 - val_accuracy: 0.7003
# Epoch 39/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.6033 - accuracy: 0.7900 - val_loss: 0.9378 - val_accuracy: 0.7083
# Epoch 40/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5627 - accuracy: 0.8064 - val_loss: 1.0270 - val_accuracy: 0.7163
# Epoch 41/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5816 - accuracy: 0.7920 - val_loss: 0.9198 - val_accuracy: 0.7131
# Epoch 42/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5701 - accuracy: 0.8076 - val_loss: 0.9176 - val_accuracy: 0.7404
# Epoch 43/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5328 - accuracy: 0.8136 - val_loss: 0.9145 - val_accuracy: 0.7340
# Epoch 44/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5183 - accuracy: 0.8236 - val_loss: 0.9922 - val_accuracy: 0.7115
# Epoch 45/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5801 - accuracy: 0.8000 - val_loss: 0.8222 - val_accuracy: 0.7500
# Epoch 46/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5223 - accuracy: 0.8144 - val_loss: 0.8269 - val_accuracy: 0.7436
# Epoch 47/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5064 - accuracy: 0.8224 - val_loss: 0.9354 - val_accuracy: 0.7292
# Epoch 48/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5031 - accuracy: 0.8236 - val_loss: 0.9441 - val_accuracy: 0.7244
# Epoch 49/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4513 - accuracy: 0.8348 - val_loss: 0.9454 - val_accuracy: 0.7772
# Epoch 50/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.5003 - accuracy: 0.8304 - val_loss: 0.9928 - val_accuracy: 0.7019
# Epoch 51/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4488 - accuracy: 0.8472 - val_loss: 0.8807 - val_accuracy: 0.7500
# Epoch 52/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4315 - accuracy: 0.8508 - val_loss: 0.9422 - val_accuracy: 0.7324
# Epoch 53/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4100 - accuracy: 0.8560 - val_loss: 1.0138 - val_accuracy: 0.7500
# Epoch 54/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4812 - accuracy: 0.8300 - val_loss: 0.9218 - val_accuracy: 0.7468
# Epoch 55/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4339 - accuracy: 0.8432 - val_loss: 0.9682 - val_accuracy: 0.7516
# Epoch 56/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4892 - accuracy: 0.8272 - val_loss: 0.9489 - val_accuracy: 0.7500
# Epoch 57/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4210 - accuracy: 0.8576 - val_loss: 0.8558 - val_accuracy: 0.7756
# Epoch 58/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.3962 - accuracy: 0.8604 - val_loss: 0.9859 - val_accuracy: 0.7564
# Epoch 59/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4013 - accuracy: 0.8572 - val_loss: 0.9405 - val_accuracy: 0.7580
# Epoch 60/60
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4345 - accuracy: 0.8564 - val_loss: 1.0365 - val_accuracy: 0.7708

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Open an embedded TensorBoard viewer
#%tensorboard --logdir {logdir}/sizes
#tensorboard dev upload --logdir logs
# Out:
#   File "/scratch/local/12484108/ipykernel_137349/2068177798.py", line 6
#     tensorboard dev upload --logdir logs
#                 ^
# SyntaxError: invalid syntax

# %%
from  IPython import display
display.IFrame(
    src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97",
    width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
